# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.iolib.summary2 import summary_col

# %%
n=10000
df=pd.DataFrame(index=range(n), columns=['x','y'])
df['x']=np.random.normal(100,15,n)
df['y']=200+2*df.x+np.random.normal(0,500,n)
reg=smf.ols('y~x', data=df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     49.73
# Date:                Tue, 25 Oct 2022   Prob (F-statistic):           1.88e-12
# Time:                        09:26:48   Log-Likelihood:                -76339.
# No. Observations:               10000   AIC:                         1.527e+05
# Df Residuals:                    9998   BIC:                         1.527e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    158.1857     33.533      4.717      0.000      92.454     223.917
# x              2.3424      0.332      7.052      0.000       1.691       2.993
# ==============================================================================
# Omnibus:                        0.522   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.770   Jarque-Bera (JB):                0.490
# Skew:                           0.012   Prob(JB):                        0.783
# Kurtosis:                       3.024   Cond. No.                         677.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(summary_col([reg], stars=True))
# Out:
# =========================
#                    y
# -------------------------
# Intercept      -73.0977
#                (156.8526)
# x              4.7465***
#                (1.5504)
# R-squared      0.0230
# R-squared Adj. 0.0206
# =========================
# Standard errors in
# parentheses.
# * p<.1, ** p<.05,
# ***p<.01

# %%
df=pd.DataFrame(index=range(n))

coeff = []


for i in range(5000):
    df['x']=np.random.normal(100,15,n)
    df['y']=200+ 2*df['x'] + np.random.normal(0,500,n)
    reg=smf.ols('y~x', data=df).fit()
    coeff.append(reg.params[1])

# %%
sns.histplot(coeff)

# %%
df=pd.DataFrame(index=range(n))

coeff0 = []


for i in range(5000):
    df['x']=np.random.normal(100,15,n)
    df['y']=200+  np.random.normal(0,500,n)
    reg=smf.ols('y~x', data=df).fit()
    coeff0.append(reg.params[1])

# %%
sns.histplot(coeff0)

# %%
coeff = []
c=0
n=400
df=pd.DataFrame(index=range(n))


for i in range(1000):
    df['x']=np.random.normal(100,15,n)
    df['y']=200+ np.random.normal(0,500,n)
    reg=smf.ols('y~x', data=df).fit()
    coeff.append(reg.params[1])
    if np.abs(reg.params[1]/reg.bse[1])>1.96:
        c=c+1

print(c)
# Out:
# 57
