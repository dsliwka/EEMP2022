# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.iolib.summary2 import summary_col

# %%
n=10000
df=pd.DataFrame(index=range(n))
df['ability']=np.random.normal(100,15,n)
df['experience']=np.random.uniform(0,30,n)
df['training']=(df.ability+ np.random.normal(0,10,n)>100)*1
df['sales']=10000+df.training*5000+df.ability*100+df.experience*15000+np.random.normal(0,4000,n)

# %%
reg1=smf.ols('sales ~ training', data=df).fit()
reg2=smf.ols('sales ~ training + experience', data=df).fit()
reg3=smf.ols('sales ~ training + ability', data=df).fit()
reg4=smf.ols('sales ~ training + ability + experience', data=df).fit()
print(summary_col([reg1,reg2,reg3,reg4], regressor_order=['training','ability','experience'], stars=True))
# Out:
# ========================================================================
#                   sales I        sales II     sales III      sales IIII
# ------------------------------------------------------------------------
# training       3408.5876      7006.4162***  1803.9002      5005.9662***
#                (2613.6396)    (83.3249)     (3480.1077)    (106.7259)
# ability                                     80.6492        100.5423***
#                                             (115.4818)     (3.5414)
# experience                    14995.9332***                14996.1584***
#                               (4.7833)                     (4.6016)
# Intercept      245662.4696*** 19019.9268*** 238399.1700*** 9961.6386***
#                (1842.9403)    (93.1538)     (10562.3729)   (331.4050)
# R-squared      0.0002         0.9990        0.0002         0.9991
# R-squared Adj. 0.0001         0.9990        0.0000         0.9991
# ========================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
reg=smf.ols('training ~ ability', data=df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               training   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     7727.
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        17:39:59   Log-Likelihood:                -4394.8
# No. Observations:               10000   AIC:                             8794.
# Df Residuals:                    9998   BIC:                             8808.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.6927      0.025    -67.186      0.000      -1.742      -1.643
# ability        0.0219      0.000     87.903      0.000       0.021       0.022
# ==============================================================================
# Omnibus:                     1226.224   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              320.967
# Skew:                           0.011   Prob(JB):                     2.01e-70
# Kurtosis:                       2.123   Cond. No.                         678.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
reg=smf.ols('training ~ ability', data=df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               training   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     7727.
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        17:39:59   Log-Likelihood:                -4394.8
# No. Observations:               10000   AIC:                             8794.
# Df Residuals:                    9998   BIC:                             8808.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.6927      0.025    -67.186      0.000      -1.742      -1.643
# ability        0.0219      0.000     87.903      0.000       0.021       0.022
# ==============================================================================
# Omnibus:                     1226.224   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              320.967
# Skew:                           0.011   Prob(JB):                     2.01e-70
# Kurtosis:                       2.123   Cond. No.                         678.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
